# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv("cardata.csv")
df.head(41)
# Out:
#    Car Model  Horsepower  Weight  MPG  Price
# 0      Car A         130    3500   22  20000
# 1      Car B         165    3700   18  25000
# 2      Car C         150    3400   20  23000
# 3      Car D         180    4000   16  27000
# 4      Car E         140    3300   24  21000
# 5      Car F         175    3600   19  26000
# 6      Car G         160    3800   21  24000
# 7      Car H         155    3200   23  22000
# 8      Car I         145    3100   25  21000
# 9      Car J         170    3900   17  25000
# 10     Car K         135    3450   21  20500
# 11     Car L         160    3550   22  24500
# 12     Car M         145    3250   23  21500
# 13     Car N         185    4150   16  27500
# 14     Car O         150    3350   24  22500
# 15     Car P         170    3650   20  25500
# 16     Car Q         155    3750   21  23500
# 17     Car R         165    3500   19  24500
# 18     Car S         140    3150   25  20500
# 19     Car T         175    3950   17  26500
# 20     Car U         160    3450   22  23500
# 21     Car V         155    3550   23  22500
# 22     Car W         145    3200   24  21500
# 23     Car X         180    4100   18  27500
# 24     Car Y         170    3350   20  25000
# 25     Car Z         165    3700   19  24500
# 26    Car AA         150    3300   23  23000
# 27    Car AB         140    3100   25  21500
# 28    Car AC         175    3800   16  26500
# 29    Car AD         160    3500   21  23500
# 30    Car AE         145    3200   22  21500
# 31    Car AF         135    3000   26  20000
# 32    Car AG         155    3650   20  22500
# 33    Car AH         170    3750   18  25500
# 34    Car AI         180    4050   17  27500
# 35    Car AJ         165    3400   22  24500
# 36    Car AK         150    3250   24  23000
# 37    Car AL         140    3150   26  21000
# 38    Car AM         175    3850   16  26000
# 39    Car AN         160    3550   21  23500
# 40    Car AO         145    3300   22  22000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Car Model   78 non-null     object
#  1   Horsepower  78 non-null     int64
#  2   Weight      78 non-null     int64
#  3   MPG         78 non-null     int64
#  4   Price       78 non-null     int64
# dtypes: int64(4), object(1)
# memory usage: 3.2+ KB

# %%
corr = df.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm', linewidths=0.5)
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_2720\1603200367.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr()

# %%
sns.scatterplot(x='Horsepower', y='Price', data=df)
plt.xlabel('Horsepower')
plt.ylabel('Price)')
plt.title('Scatter Plot of Horsepower vs Price')
plt.show()

# %%
sns.scatterplot(x='Horsepower', y='MPG', data=df)
plt.xlabel('Horsepower')
plt.ylabel('Miles per Gallon (MPG)')
plt.title('Scatter Plot of Horsepower vs MPG')
plt.show()

# %%
X = df.drop(['Car Model', 'Price'], axis =1)
X.head()
# Out:
#    Horsepower  Weight  MPG
# 0         130    3500   22
# 1         165    3700   18
# 2         150    3400   20
# 3         180    4000   16
# 4         140    3300   24

# %%
y = df['Price']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 42, shuffle = True, test_size = 0.3)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape,
# Out:
# ((54, 3), (24, 3), (54,), (24,))

# %%
y_train.shape
# Out:
# (54,)

# %%
from sklearn.linear_model import LinearRegression

# %%
linear_model = LinearRegression()

# %%
linear_model.fit(X_train ,y_train)
# Out:
# LinearRegression()

# %%
# We can find each of the coeff by this method

linear_model.coef_
# Out:
# array([140.66257054,   0.40105057,   2.50961661])

# %%
# To find intercept we use this 

model.intercept_
# Out:
# -32.64925867376951

# %%
X_test
# Out:
#     Horsepower  Weight  MPG
# 33         170    3750   18
# 0          130    3500   22
# 34         180    4050   17
# 12         145    3250   23
# 10         135    3450   21
# 77         140    3150   26
# 30         145    3200   22
# 4          140    3300   24
# 49         160    3500   21
# 66         150    3200   24
# 61         135    3050   25
# 22         145    3200   24
# 72         155    3650   20
# 54         180    4050   17
# 18         140    3150   25
# 44         180    4000   17
# 31         135    3000   26
# 58         175    3850   16
# 9          170    3900   17
# 5          175    3600   19
# 35         165    3400   22
# 39         160    3550   21
# 67         140    3100   26
# 53         170    3750   18

# %%
y_test
# Out:
# 33    25500
# 0     20000
# 34    27500
# 12    21500
# 10    20500
# 77    21000
# 30    21500
# 4     21000
# 49    23500
# 66    23000
# 61    20500
# 22    21500
# 72    22500
# 54    27500
# 18    20500
# 44    27000
# 31    20000
# 58    26000
# 9     25000
# 5     26000
# 35    24500
# 39    23500
# 67    21000
# 53    25500
# Name: Price, dtype: int64

# %% [markdown]
# #### Now that we got the values, lets predict the price for record 1

# %%
X_train.head(1)
# Out:
#     Horsepower  Weight  MPG
# 40         145    3300   22

# %%
price = -32.649 + (140.66*145) + (0.40*3300) + (2.5 * 22)
price
# Out:
# 21738.051

# %%
y_train.head(1)
# Out:
# 40    22000
# Name: Price, dtype: int64

# %% [markdown]
# #### By using our model we predicted 19686.45 but the actual value is 20000. This means the error for this is 316.59

# %% [markdown]
# Let's see how our model performed in broad view meaning we will be checking the metrics r2 score.

# %%
y_pred = linear_model.predict(X_test)
y_pred
# Out:
# array([25429.10046514, 19712.3734677 , 26953.53172455, 21724.55900031,
#        20393.12417537, 20988.66994057, 21701.99685526, 21043.80829263,
#        23929.74096739, 22410.3289412 , 20242.74241437, 21707.01608849,
#        23284.07608335, 26953.53172455, 20986.16032395, 26933.47919612,
#        20225.19950255, 26167.4991415 , 25486.74843382, 26074.76534918,
#        24595.45837986, 23949.79349582, 20968.61741213, 25429.10046514])

# %% [markdown]
# The values which we have mgot here is the price result for all the records. Now let's see the result

# %%
from sklearn.metrics import r2_score

# %%
print("The r2 score is:", r2_score(y_pred, y_test))
# Out:
# The r2 score is: 0.9800638355010262

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, root_mean_squared_error

# %%
print(mean_squared_error(y_pred, y_test))
print(root_mean_squared_error(y_pred, y_test))
mean_absolute_error(y_pred, y_test)
# Out:
# 117725.48800086633
# 343.11148042708555
# 269.25924946858805

# %% [markdown]
# We can see that the model is performing very well, we know that by analyzing the r2 score, 0.96 means it is 96% accurate.`

# %% [markdown]
# #### Suppose we have to predict the price of a new car, for this we only know hp, weight and mpg

# %%
new_car = pd.DataFrame({
    'Horsepower': [200],
    'Weight': [2000],
    'MPG': [40]
})

new_car
# Out:
#    Horsepower  Weight  MPG
# 0         200    2000   40

# %%
y_pred = linear_model.predict(new_car)
y_pred
# Out:
# array([29002.35065182])
