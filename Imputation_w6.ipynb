# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Quandl.csv', parse_dates = ['Year'])
df.head(50)
# Out:
#          Year  S&P Composite   Dividend   Earnings    CPI  Long Interest Rate  \
# 0  2000-01-31        1425.59  16.713333        NaN  168.8                6.66
# 1  2000-02-29        1388.87  16.736667  50.023333  169.8                6.52
# 2  2000-03-31        1442.21  16.760000  50.950000  171.2                6.26
# 3  2000-04-30        1461.36  16.740000  51.273333  171.3                5.99
# 4  2000-05-31        1418.48        NaN  51.596667  171.5                6.44
# 5  2000-06-30        1461.96        NaN        NaN  172.4                6.10
# 6  2000-07-31        1473.00  16.583333  52.513333  172.8                6.05
# 7  2000-08-31        1485.46        NaN  53.106667  172.8                5.83
# 8  2000-09-30        1468.05        NaN        NaN  173.7                5.80
# 9  2000-10-31        1390.14        NaN        NaN  174.0                5.74
# 10 2000-11-30        1378.04  16.296667  51.233333  174.1                5.72
# ...

# %%
df.iloc[29:32, :]
# Out:
#          Year  S&P Composite  Dividend  Earnings    CPI  Long Interest Rate  \
# 29 2002-06-30        1014.02     16.04     26.74  179.9                4.93
# 30 2002-07-31         903.59       NaN     27.84  180.1                4.65
# 31 2002-08-31         912.55     15.88     28.94  180.7                4.26
#
#      Real Price  Real Dividend  Real Earnings  Cyclically Adjusted PE Ratio
# 29  1661.021408      26.274416      43.801614                           NaN
# 30  1478.487222      26.114340      45.552833                     23.463120
# 31  1488.190025      25.897165      47.195463                     23.588714

# %%
df.iloc[7:11, 3:]
# Out:
#      Earnings    CPI  Long Interest Rate   Real Price  Real Dividend  \
# 7   53.106667  172.8                5.83  2533.244427      28.081599
# 8         NaN  173.7                5.80  2490.582322      27.738170
# 9         NaN  174.0                5.74  2354.339906      27.645183
# 10  51.233333  174.1                5.72  2332.506835      27.584168
#
#     Real Earnings  Cyclically Adjusted PE Ratio
# 7       90.565998                     42.869565
# 8       91.103348                     41.898008
# 9       88.857501                     39.369699
# 10      86.718891                     38.782142

# %%
df.iloc[35:39, 6:]
# Out:
#      Real Price  Real Dividend  Real Earnings  Cyclically Adjusted PE Ratio
# 35  1464.764966      26.178043      44.944133                     23.101443
# 36  1452.898900      26.143876      46.222114                           NaN
# 37  1347.139442      26.024449      47.333275                           NaN
# 38  1354.452876      25.949028      48.506445                     21.309719

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271 entries, 0 to 270
# Data columns (total 10 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Year                          271 non-null    datetime64[ns]
#  1   S&P Composite                 271 non-null    float64
#  2   Dividend                      192 non-null    float64
#  3   Earnings                      178 non-null    float64
#  4   CPI                           271 non-null    float64
#  5   Long Interest Rate            271 non-null    float64
#  6   Real Price                    271 non-null    float64
#  7   Real Dividend                 271 non-null    float64
#  8   Real Earnings                 271 non-null    float64
#  9   Cyclically Adjusted PE Ratio  193 non-null    float64
# dtypes: datetime64[ns](1), float64(9)
# memory usage: 21.3 KB

# %%
df.isna().sum()
# Out:
# Year                             0
# S&P Composite                    0
# Dividend                        79
# Earnings                        93
# CPI                              0
# Long Interest Rate               0
# Real Price                       0
# Real Dividend                    0
# Real Earnings                    0
# Cyclically Adjusted PE Ratio    78
# dtype: int64

# %% [markdown]
# ### 1. Dividend

# %%
pd.DataFrame(df["Dividend"].describe())
# Out:
#          Dividend
# count  192.000000
# mean    33.304676
# std     15.398930
# min     15.690000
# 25%     21.065000
# 50%     27.415000
# 75%     46.210000
# max     64.020000

# %%
sns.boxplot(data = df, y= 'Dividend');

# %%
plt.figure(figsize = (8,5))
sns.lineplot(data = df, x = 'Year', y= 'Dividend');

# %%
sns.histplot(data = df, x= 'Dividend', kde = True)
# Out:
# <Axes: xlabel='Dividend', ylabel='Count'>

# %%
df['Dividend'] = df['Dividend'].interpolate()

# %%
df.iloc[29:32, :]
# Out:
#          Year  S&P Composite  Dividend  Earnings    CPI  Long Interest Rate  \
# 29 2002-06-30        1014.02     16.04     26.74  179.9                4.93
# 30 2002-07-31         903.59     15.96     27.84  180.1                4.65
# 31 2002-08-31         912.55     15.88     28.94  180.7                4.26
#
#      Real Price  Real Dividend  Real Earnings  Cyclically Adjusted PE Ratio
# 29  1661.021408      26.274416      43.801614                           NaN
# 30  1478.487222      26.114340      45.552833                     23.463120
# 31  1488.190025      25.897165      47.195463                     23.588714

# %% [markdown]
# ### 2. Earning

# %%
pd.DataFrame(df["Earnings"].describe())
# Out:
#          Earnings
# count  178.000000
# mean    78.635169
# std     37.232413
# min      7.076667
# 25%     51.243333
# 50%     83.510000
# 75%     98.809167
# max    197.910000

# %%
sns.boxplot(data = df, y= 'Earnings');

# %%
plt.figure(figsize = (8,5))
sns.lineplot(data = df, x = 'Year', y= 'Earnings');

# %%
df['Earnings'] = df['Earnings'].ffill()

# %%
df.iloc[7:11, 3:]
# Out:
#      Earnings    CPI  Long Interest Rate   Real Price  Real Dividend  \
# 7   53.106667  172.8                5.83  2533.244427      28.081599
# 8   53.106667  173.7                5.80  2490.582322      27.738170
# 9   53.106667  174.0                5.74  2354.339906      27.645183
# 10  51.233333  174.1                5.72  2332.506835      27.584168
#
#     Real Earnings  Cyclically Adjusted PE Ratio
# 7       90.565998                     42.869565
# 8       91.103348                     41.898008
# 9       88.857501                     39.369699
# 10      86.718891                     38.782142

# %%
df.tail(10)
# Out:
#           Year  S&P Composite   Dividend  Earnings        CPI  \
# 261 2021-10-31    4460.707143  59.635361    182.91  276.58900
# 262 2021-11-30    4667.386667  60.016239    190.39  277.94800
# 263 2021-12-31    4674.772727  60.397117    197.87  278.80200
# 264 2022-01-31    4573.815500  60.921403    197.87  281.14800
# 265 2022-02-28    4435.980526  61.445689    197.87  283.71600
# 266 2022-03-31    4391.265217  62.076012    197.91  287.50400
# 267 2022-04-30    4391.296000  62.706335    197.91  289.10900
# 268 2022-05-31    4040.360000  63.336658    197.91  292.29600
# 269 2022-06-30    3898.946667  64.020000    197.91  293.88950
# 270 2022-07-31    3831.390000  64.020000    197.91  294.68625
#
#      Long Interest Rate   Real Price  Real Dividend  Real Earnings  \
# 261                1.58  4752.571723      63.537309     194.877822
# 262                1.56  4948.460410      63.630465     201.855437
# 263                1.47  4941.109621      63.838136     209.143293
# ...

# %%
sns.histplot(data = df, x= 'Earnings', kde = True)
# Out:
# <Axes: xlabel='Earnings', ylabel='Count'>

# %% [markdown]
# ### 3. Cyclically Adjusted PE Ratio

# %%
pd.DataFrame(df["Cyclically Adjusted PE Ratio"].describe())
# Out:
#        Cyclically Adjusted PE Ratio
# count                    193.000000
# mean                      27.130325
# std                        6.005063
# min                       13.323668
# 25%                       23.348396
# 50%                       26.148607
# 75%                       30.195583
# max                       43.772578

# %%
sns.boxplot(data = df, y= 'Cyclically Adjusted PE Ratio');

# %%
plt.figure(figsize = (8,5))
sns.lineplot(data = df, x = 'Year', y= 'Cyclically Adjusted PE Ratio');

# %%
df['Cyclically Adjusted PE Ratio'] = df['Cyclically Adjusted PE Ratio'].bfill()

# %%
df.iloc[35:39, 6:]
# Out:
#      Real Price  Real Dividend  Real Earnings  Cyclically Adjusted PE Ratio
# 35  1464.764966      26.178043      44.944133                     23.101443
# 36  1452.898900      26.143876      46.222114                     21.309719
# 37  1347.139442      26.024449      47.333275                     21.309719
# 38  1354.452876      25.949028      48.506445                     21.309719

# %%
df.isna().sum()
# Out:
# Year                            0
# S&P Composite                   0
# Dividend                        0
# Earnings                        1
# CPI                             0
# Long Interest Rate              0
# Real Price                      0
# Real Dividend                   0
# Real Earnings                   0
# Cyclically Adjusted PE Ratio    1
# dtype: int64

# %%
sns.histplot(data = df, x= 'Cyclically Adjusted PE Ratio', kde = True)
# Out:
# <Axes: xlabel='Cyclically Adjusted PE Ratio', ylabel='Count'>
